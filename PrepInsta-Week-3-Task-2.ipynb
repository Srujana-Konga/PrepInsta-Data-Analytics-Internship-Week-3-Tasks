# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("E:\chipotle.tsv",sep='\t')

# %%
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
data.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
data.tail()
# Out:
#       order_id  quantity           item_name  \
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
data.shape
# Out:
# (4622, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
data.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
data_ = {
    'Order_Id': data['order_id'],
    'Quantity': data['quantity'],
    'Item_name':data['item_name'],
    'Choice_description': data['choice_description'],
    'Item_price': data['item_price']
}

df = pd.DataFrame(data_)
#display(df.style.hide_index())
df
# Out:
#       Order_Id  Quantity                              Item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      Choice_description Item_price
# 0                                                   NaN     $2.39
# ...

# %% [markdown]
# ## Question 2

# %%
data.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
data.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
data['item_price'] = data['item_price'].str.replace('$',' ')
data
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN      2.39
# ...

# %%
df['Item_price'] = pd.to_numeric(df['Item_price'], errors = 'coerce', downcast = 'integer')
df.dtypes
# Out:
# Order_Id                int64
# Quantity                int64
# Item_name              object
# Choice_description     object
# Item_price            float64
# dtype: object

# %% [markdown]
# ## Question 3

# %%
duplicates = df[data.duplicated()]
df.duplicated().sum()
# Out:
# 59

# %%
df_no_duplicates = data.drop_duplicates()
df_no_duplicates
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN      2.39
# ...

# %% [markdown]
# ## Question 4

# %%
df['Item_price'] = data['item_price']
df[['Quantity','Item_price']]
# Out:
#       Quantity Item_price
# 0            1      2.39
# 1            1      3.39
# 2            1      3.39
# 3            1      2.39
# 4            2     16.98
# ...        ...        ...
# 4617         1     11.75
# 4618         1     11.75
# 4619         1     11.25
# 4620         1      8.75
# 4621         1      8.75
#
# [4622 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
data = np.random.randn(100)

plt.boxplot(data)
plt.ylabel('Value')
plt.title('Box Plot')
plt.show()

# %% [markdown]
# ## Question 5

# %%
df
# Out:
#       Order_Id  Quantity                              Item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      Choice_description  Item_price
# 0                                                  None        2.39
# ...

# %% [markdown]
# ## Question 6

# %%
df
# Out:
#       Order_Id  Quantity                              Item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      Choice_description Item_price
# 0                                                   NaN      2.39
# ...

# %%
df.Choice_description.isna().sum()
# Out:
# 1246

# %%
df['Choice_description'].replace({np.NaN : None}, inplace = True)
df
# Out:
#       Order_Id  Quantity                              Item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      Choice_description Item_price
# 0                                                  None      2.39
# ...

# %%
df.dtypes
# Out:
# Order_Id               int64
# Quantity               int64
# Item_name             object
# Choice_description    object
# Item_price            object
# dtype: object

# %% [markdown]
# ## Question 7

# %%
missing_values = df['Order_Id'].isnull().sum()
missing_values
# Out:
# 0

# %%
duplicate_values = df['Order_Id'].duplicated().sum()
duplicate_values
# Out:
# 2788

# %%
cross_reference = df.groupby('Order_Id').nunique()
cross_reference
# Out:
#           Quantity  Item_name  Choice_description  Item_price
# Order_Id
# 1                1          4                   2           2
# 2                1          1                   1           1
# 3                1          2                   1           2
# 4                1          2                   2           2
# 5                1          2                   1           2
# ...            ...        ...                 ...         ...
# 1830             1          2                   2           2
# 1831             1          3                   1           3
# 1832             1          2                   1           2
# 1833             1          1                   2           1
# 1834             1          1                   3           2
#
# [1834 rows x 4 columns]

# %%
unique_values = df['Order_Id'].nunique()
unique_values
# Out:
# 1834

# %% [markdown]
# ## Question 8

# %%
df['Item_name'].unique()
# Out:
# array(['Chips and Fresh Tomato Salsa', 'Izze', 'Nantucket Nectar',
#        'Chips and Tomatillo-Green Chili Salsa', 'Chicken Bowl',
#        'Side of Chips', 'Steak Burrito', 'Steak Soft Tacos',
#        'Chips and Guacamole', 'Chicken Crispy Tacos',
#        'Chicken Soft Tacos', 'Chicken Burrito', 'Canned Soda',
#        'Barbacoa Burrito', 'Carnitas Burrito', 'Carnitas Bowl',
#        'Bottled Water', 'Chips and Tomatillo Green Chili Salsa',
#        'Barbacoa Bowl', 'Chips', 'Chicken Salad Bowl', 'Steak Bowl',
#        'Barbacoa Soft Tacos', 'Veggie Burrito', 'Veggie Bowl',
#        'Steak Crispy Tacos', 'Chips and Tomatillo Red Chili Salsa',
#        'Barbacoa Crispy Tacos', 'Veggie Salad Bowl',
#        'Chips and Roasted Chili-Corn Salsa',
#        'Chips and Roasted Chili Corn Salsa', 'Carnitas Soft Tacos',
#        'Chicken Salad', 'Canned Soft Drink', 'Steak Salad Bowl',
#        '6 Pack Soft Drink', 'Chips and Tomatillo-Red Chili Salsa', 'Bowl',
# ...

# %%
df.groupby('Item_name')['Quantity'].sum().sort_values(ascending=False)
# Out:
# Item_name
# Chicken Bowl                             761
# Chicken Burrito                          591
# Chips and Guacamole                      506
# Steak Burrito                            386
# Canned Soft Drink                        351
# Chips                                    230
# Steak Bowl                               221
# Bottled Water                            211
# Chips and Fresh Tomato Salsa             130
# Canned Soda                              126
# Chicken Salad Bowl                       123
# Chicken Soft Tacos                       120
# Side of Chips                            110
# Veggie Burrito                            97
# Barbacoa Burrito                          91
# Veggie Bowl                               87
# Carnitas Bowl                             71
# Barbacoa Bowl                             66
# Carnitas Burrito                          60
# Steak Soft Tacos                          56
# 6 Pack Soft Drink                         55
# ...

# %% [markdown]
# ## Question 9

# %%
type(df.Item_price)
# Out:
# pandas.core.series.Series

# %%
df.Item_price.dtype
# Out:
# dtype('O')

# %%
df['Item_price'] = df['Item_price'].astype(float)

# %%
df.Item_price.sum()
# Out:
# 34500.16

# %%
df[['Quantity','Item_price']]
# Out:
#       Quantity  Item_price
# 0            1        2.39
# 1            1        3.39
# 2            1        3.39
# 3            1        2.39
# 4            2       16.98
# ...        ...         ...
# 4617         1       11.75
# 4618         1       11.75
# 4619         1       11.25
# 4620         1        8.75
# 4621         1        8.75
#
# [4622 rows x 2 columns]

# %% [markdown]
# ## Question 10

# %%
cross_references = df.groupby(['Item_name', 'Choice_description'])[['Quantity', 'Item_price']].sum()
cross_references
# Out:
#                                                                       Quantity  \
# Item_name         Choice_description
# 6 Pack Soft Drink [Coke]                                                    21
#                   [Diet Coke]                                               25
#                   [Lemonade]                                                 2
#                   [Nestea]                                                   2
#                   [Sprite]                                                   5
# ...                                                                        ...
# Veggie Soft Tacos [Fresh Tomato Salsa, [Black Beans, Cheese, Sour...         1
#                   [Fresh Tomato Salsa, [Fajita Vegetables, Rice, ...         1
#                   [Roasted Chili Corn Salsa (Medium), [Black Bean...         1
#                   [Roasted Chili Corn Salsa, [Fajita Vegetables, ...         1
# ...

# %% [markdown]
# ## Question 11

# %%
file_path = "E:\chipotle.tsv"
df.to_csv(file_path, index = False)

# %% [markdown]
# ## Question 12

# %%
df
# Out:
#       Order_Id  Quantity                              Item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      Choice_description  Item_price
# 0                                                  None        2.39
# ...

# %% [markdown]
# ## Question 13

# %%
df.dtypes
# Out:
# Order_Id                int64
# Quantity                int64
# Item_name              object
# Choice_description     object
# Item_price            float64
# dtype: object
